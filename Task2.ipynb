# %% [markdown]
# <a href="https://colab.research.google.com/github/anshita647/Learning_of_AI_and_ML/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Titanic DataSet

# %% [markdown]
# Loading of dataSet:

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df=pd.read_csv(url)
print("First 5 rows:\n",df.head())
print("No of rows and columns:",df.shape)
# Out:
# First 5 rows:
#     PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# No of rows and columns: (891, 12)

# %% [markdown]
# Cleaning of data

# %%
print(df.isnull().sum())
df.drop("Cabin", axis=1, inplace=True, errors="ignore")
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])
df.rename(columns={"Pclass": "PassengerClass"}, inplace=True)
print(df.head())
# Out:
# PassengerId       0
# Survived          0
# PassengerClass    0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Embarked          0
# dtype: int64
#    PassengerId  Survived  PassengerClass  \
# 0            1         0               3
# 1            2         1               1
# 2            3         1               3
# 3            4         1               1
# 4            5         0               3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %% [markdown]
# Analyze the Data(groupby,aggregation,pivot table)

# %%
print("Survival rate by gender:\n",df.groupby("Sex")["Survived"].mean())
print("Survival rate by Passenger class:\n",df.groupby("PassengerClass")["Survived"].mean())
print("Average fare by passenger class:\n",df.groupby("PassengerClass")["Fare"].mean())
# Out:
# Survival rate by gender:
#  Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
# Survival rate by Passenger class:
#  PassengerClass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64
# Average fare by passenger class:
#  PassengerClass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
pivot=pd.pivot_table(df,values="Survived",index="Sex",columns="PassengerClass",aggfunc="mean")
print("Table:\n",pivot)
# Out:
# Table:
#  PassengerClass         1         2         3
# Sex
# 0               0.368852  0.157407  0.135447
# 1               0.968085  0.921053  0.500000

# %% [markdown]
# Export Summary

# %%
df.to_csv("Cleaned_Titanic.csv",index=False)
pivot.to_excel("titanic_summary.xlsx")

# %%
from google.colab import files
files.download("Cleaned_Titanic.csv")
files.download("titanic_summary.xlsx")
